# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Define a function
# ## y = f(x) = 5x + 0.5

# %%
def f(x):
    return 5*x + 0.5

# %% [markdown]
# ## Method 1: Iteration

# %%
x_list = range(10)
for x in x_list:
    print(f(x))
# Out:
# 0.5
# 5.5
# 10.5
# 15.5
# 20.5
# 25.5
# 30.5
# 35.5
# 40.5
# 45.5

# %% [markdown]
# ## Method 2: List appending

# %%
x_list = range(10)
y_list = []
for x in x_list:
    y = f(x)
    y_list.append(y)
print(y_list)
# Out:
# [0.5, 5.5, 10.5, 15.5, 20.5, 25.5, 30.5, 35.5, 40.5, 45.5]

# %% [markdown]
# ## Method 3: List comprehension

# %%
x_list = range(10)
y_list = [f(x) for x in x_list]
print(y_list)
# Out:
# [0.5, 5.5, 10.5, 15.5, 20.5, 25.5, 30.5, 35.5, 40.5, 45.5]

# %% [markdown]
# ## Method 4: Map

# %%
x_list = range(10)
y_list = map(f, x_list)
print(y_list)
# Out:
# [0.5, 5.5, 10.5, 15.5, 20.5, 25.5, 30.5, 35.5, 40.5, 45.5]

# %% [markdown]
# ## Method 5: Numpy Arrays

# %%
x_list = np.arange(10)
y_list = f(x_list)
print(y_list)
# Out:
# [  0.5   5.5  10.5  15.5  20.5  25.5  30.5  35.5  40.5  45.5]

# %% [markdown]
# # PLOT: X and Y

# %%
def f(x):
    return ((x**2) / 10.0) + 2.5

x = np.arange(1000)
y = f(x)

plt.figure()
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# # Python Exploration
# - Variables
# - `print` statment
# - Dictionaries
#     - How to create dictionaries
#     - How to add items to a dictionary
# - Lists
#     - How to create dictionaries
#     - How to add items to a dictionary
# - For loop / iteration
#     - Simple for loop; iterate over a list
#     - For loop with `enumerate` keyword
# - Functions
#     - How to define a function
#     - How to add parameters or arguments to a function
#     - How to return values
